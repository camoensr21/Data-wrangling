# %% [markdown]
# # INTRODUCTION TO THE PROJECT
#
# This project is about wrangling, assessing and cleaning for analysis purpose.
#
# The goal: wrangle WeRateDogs Twitter data to create interesting and trustworthy analyses and visualizations. The Twitter archive is great, but it only contains very basic tweet information. Additional gathering, then assessing and cleaning is required for "Wow!"-worthy analyses and visualizations.
#
# ## What are the data and where they come from?
#
# The data which will be used are about people's dogs rating. The dataset that will be wrangled (and analyzed and visualized) is the tweet archive of Twitter user @dog_rates, also known as WeRateDogs. WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog. These ratings almost always have a denominator of 10. The numerators, though? Almost always greater than 10. 11/10, 12/10, 13/10, etc. Why? Because "they're good dogs Brent." WeRateDogs has over 4 million followers and has received international media coverage.
#
#
# ## Where those data come from?
#
# For this project we have three sources for the data:
#
# 1) Enhanced Twitter Archive, which comes on a csv file fomat:
#
# The WeRateDogs Twitter archive contains basic tweet data for all 5000+ of their tweets, but not everything. One column the archive does contain though: each tweet's text, which are used to extract rating, dog name, and dog "stage" (i.e. doggo, floofer, pupper, and puppo) to make this Twitter archive "enhanced." Of the 5000+ tweets, the author has filtered for tweets with ratings only (there are 2356).
#
# 2) Additional Data via the Twitter API
#
# Back to the basic-ness of Twitter archives: retweet count and favorite count are two of the notable column omissions. Fortunately, this additional data can be gathered by anyone from Twitter's API. Well, "anyone" who has access to data for the 3000 most recent tweets, at least. The WeRateDogs Twitter archive and specifically the tweet IDs within it, will allow gathering this data for all 5000+. We're going to query Twitter's API to gather this valuable data.
#
# 3) Image Predictions File
#
# The author ran every image in the WeRateDogs Twitter archive through a neural network that can classify breeds of dogs*. The results: a table full of image predictions (the top three only) alongside each tweet ID, image URL, and the image number that corresponded to the most confident prediction (numbered 1 to 4 since tweets can have up to four images).

# %% [markdown]
# # GATHERING THE DATA
#
# data are available from three differents sources, which will require programmatic gathering according to the format and the source of the data.
#
# Three pieces of data will be gathered :
#
# 1. The WeRateDogs Twitter archive, which is a .csv format : twitter_archive_enhanced.csv
#
# 2. The tweet image predictions, i.e., what breed of dog (or other object, animal, etc.) is present in each tweet according to a neural network. This file (image_predictions.tsv) is hosted on a server.
#
# 3. Each tweet's retweet count and favorite ("like") count at minimum, and any interesting additional data you find interesting.

# %%
# let's import all the librairies needed for this project
import pandas as pd
import tweepy
import numpy as np
import requests
import json
import os

# %%
# let's create a pandas dataframe from the first piece of data : " twitter_archive_enhanced.csv "
twiter_archive_enhance=pd.read_csv('twitter-archive-enhanced.csv')

# %%
twiter_archive_enhance.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
twiter_archive_enhance.shape
# Out:
# (2356, 17)

# %% [markdown]
# the first piece of data has 2356 tweets of the 5000+ tweets. Those are tweets with ratings only.

# %%
# let's gather data from the second piece of data : "image_predictions.tsv"
url='https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response=requests.get(url)

# %%
# let's save tsv to file
with open('image-predictions.tsv', mode='wb') as file:
    file.write(response.content)

# %%
# Let's create a dataframe with 'image-predictions.tsv'
image_predictions=pd.read_csv('image-predictions.tsv', sep='\t')

# %%
image_predictions
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %% [markdown]
# third piece of data the tweets text. I want to get access to the WeRateDogs Twitter. Query the Twitter API for each tweet's JSON data using Python's Tweepy library and store each tweet's entire set of JSON data in a file called tweet_json.txt file. Each tweet's JSON data should be written to its own line. Then read this .txt file line by line into a pandas DataFrame with (at minimum) tweet ID, retweet count, and favorite count.
# I create a twitter app, to get authentification.

# %%
# I create a dictionary to store my twitter credentials  
import json
twitter_cred=dict()

twitter_cred['CONSUMER_KEY'] = ''
twitter_cred['CONSUMER_SECRET'] = ''
twitter_cred['ACCESS_KEY'] = ''
twitter_cred['ACCESS_SECRET'] =''

# Let's save the information to a json so that it can be reused in code without exposing
# the secret info to public

with open('twitter_credentials.json','w') as secret_info:
    json.dump(twitter_cred,secret_info, indent=4, sort_keys=True)

# %%
import tweepy, json
from tweepy import OAuthHandler
from timeit import default_timer as timer
import datetime
from datetime import datetime
import csv
import re

# load Twitter API credentials

with open('twitter_credentials.json') as cred_data:
    info=json.load(cred_data)
access_token=info['ACCESS_KEY']
access_token_secret=info['ACCESS_SECRET']
consumer_key=info['CONSUMER_KEY']
consumer_secret=info['CONSUMER_SECRET']

try:
    api.verify_credentials()
    print("Authentication Ok")
except:
    print("Error during authentication")
# Out:
# Authentication Ok

# %%
tweet_ids=twiter_archive_enhance.tweet_id.values
len(tweet_ids)
# Out:
# 2356

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth,wait_on_rate_limit=True)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive

count=0
fails_dict={}
start=timer()

# Save each tweet's returned JSON as a new line in a .txt file

with open('tweet_json.txt', 'w') as outfile:
    for tweet_id in tweet_ids :
        count += 1 
        print(str(count) + ": " + str(tweet_id)) 
        
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id]=e
            pass
end=timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %%
# Import package
import json

# String of path to file: tweets_data_path
tweets_data_path='tweet_json.txt'

# Initialize empty list to store tweets: tweets_data
tweets_data=[]

# Open connection to file
tweets_file = open(tweets_data_path, "r")

# Read in tweets and store in list: tweets_data
for line in tweets_file:
    tweet=json.loads(line)
    tweets_data.append(tweet)

# Close connection to file
tweets_file.close()

# Print the keys of the first tweet dict
print(tweets_data[0].keys())
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'full_text', 'truncated', 'display_text_range', 'entities', 'extended_entities', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'possibly_sensitive_appealable', 'lang'])

# %% [markdown]
# #### Twitter data to DataFrame

# %%
# Import package
import pandas as pd

# Build DataFrame from tweets_data for some specifics columns which will be considered as 
# additionnal data to the enhanched twitter archives
add_data= pd.DataFrame(tweets_data, columns=['created_at','id','full_text','in_reply_to_status_id','in_reply_to_user_id','retweet_count','favorite_count','favorited','retweeted','lang'])

# Print head of DataFrame
print(add_data.head())
# Out:
#                        created_at                  id  \
# 0  Tue Aug 01 16:23:56 +0000 2017  892420643555336193
# 1  Tue Aug 01 00:17:27 +0000 2017  892177421306343426
# 2  Mon Jul 31 00:18:03 +0000 2017  891815181378084864
# 3  Sun Jul 30 15:58:51 +0000 2017  891689557279858688
# 4  Sat Jul 29 16:00:24 +0000 2017  891327558926688256
#
#                                            full_text  in_reply_to_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                    NaN
# 1  This is Tilly. She's just checking pup on you....                    NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                    NaN
# 3  This is Darla. She commenced a snooze mid meal...                    NaN
# 4  This is Franklin. He would like you to stop ca...                    NaN
#
#    in_reply_to_user_id  retweet_count  favorite_count  favorited  retweeted  \
# 0                  NaN           7820           36688      False      False
# ...

# %%
add_data.shape
# Out:
# (2333, 10)

# %% [markdown]
# # Chapter 2 : Assessing Data

# %% [markdown]
# for the assessment, we will verify quality issues and structural issues in the data from each table. For the quality issues, we will refer to the content of each variable or columns from each table, for the structural aspect we will analyse each columns headers and rows.
# The assessment will be done for each table separately:
# 1. twiter_archive_enhance
# 2. image_predictions
# 3. add_data

# %% [markdown]
# For the quality assessment we will consider those four dimensions:
# completeness, for missing values
# validity: Do the values fit to the scheme of the variable?
# Accuracy: Do the values make sense?
# Consistency

# %% [markdown]
# ## Assessment of twiter_archive_enchance

# %%
twiter_archive_enhance.sample()
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 155  861769973181624320                    NaN                  NaN
#
#                      timestamp  \
# 155  2017-05-09 02:29:07 +0000
#
#                                                 source  \
# 155  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 155  RT @dog_rates: "Good afternoon class today we'...         8.066291e+17
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 155              4.196984e+09  2016-12-07 22:38:52 +0000
#
#                                          expanded_urls  rating_numerator  \
# 155  https://twitter.com/dog_rates/status/806629075...                13
#
#      rating_denominator  name doggo floofer pupper puppo
# 155                  10  None  None    None   None  None

# %%
list(twiter_archive_enhance)
# Out:
# ['tweet_id',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'timestamp',
#  'source',
#  'text',
#  'retweeted_status_id',
#  'retweeted_status_user_id',
#  'retweeted_status_timestamp',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo']

# %%
# let's assess completeness
twiter_archive_enhance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# ### Quality issues for twiter_archive_enhance
#
# Missing information for : in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls.
#
# erroneous data types for:
# tweet_id is an object not integer
# timestamp is datetime not object
#
# not proper format for timestamp
#
# ### Tidyness issues for twiter_archive_enhance
# text column should be split into followers and tweet_text
# we have four columns for dog stage, we do need just one column

# %%
twiter_archive_enhance[~ twiter_archive_enhance['in_reply_to_status_id'].isnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# ...                  ...                    ...                  ...
# 2038  671550332464455680           6.715449e+17         4.196984e+09
# 2149  669684865554620416           6.693544e+17         4.196984e+09
# 2169  669353438988365824           6.678065e+17         4.196984e+09
# 2189  668967877119254528           6.689207e+17         2.143566e+07
# 2298  667070482143944705           6.670655e+17         4.196984e+09
#
#                       timestamp  \
# 30    2017-07-15 16:51:35 +0000
# 55    2017-07-02 21:58:53 +0000
# 64    2017-06-27 12:14:36 +0000
# ...

# %%
twiter_archive_enhance[twiter_archive_enhance.text.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ## Assessment of image_predictions

# %%
list(image_predictions)
# Out:
# ['tweet_id',
#  'jpg_url',
#  'img_num',
#  'p1',
#  'p1_conf',
#  'p1_dog',
#  'p2',
#  'p2_conf',
#  'p2_dog',
#  'p3',
#  'p3_conf',
#  'p3_dog']

# %%
image_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
image_predictions.p1.value_counts()
# Out:
# golden_retriever      150
# Labrador_retriever    100
# Pembroke               89
# Chihuahua              83
# pug                    57
#                      ...
# barbell                 1
# robin                   1
# damselfly               1
# tailed_frog             1
# studio_couch            1
# Name: p1, Length: 378, dtype: int64

# %%
list(image_predictions.p1)
# Out:
# ['Welsh_springer_spaniel',
#  'redbone',
#  'German_shepherd',
#  'Rhodesian_ridgeback',
#  'miniature_pinscher',
#  'Bernese_mountain_dog',
#  'box_turtle',
#  'chow',
#  'shopping_cart',
#  'miniature_poodle',
#  'golden_retriever',
#  'Gordon_setter',
#  'Walker_hound',
#  'pug',
#  'bloodhound',
#  'Lhasa',
#  'English_setter',
#  'hen',
#  'desktop_computer',
#  'Italian_greyhound',
#  'Maltese_dog',
#  'three-toed_sloth',
#  'ox',
#  'golden_retriever',
#  'malamute',
#  'guinea_pig',
#  'soft-coated_wheaten_terrier',
#  'Chihuahua',
#  'black-and-tan_coonhound',
#  'coho',
#  'toy_terrier',
#  'Blenheim_spaniel',
#  'Pembroke',
#  'llama',
#  'Chesapeake_Bay_retriever',
#  'Chihuahua',
#  'curly-coated_retriever',
#  'dalmatian',
#  'Ibizan_hound',
#  'Border_collie',
#  'German_shepherd',
#  'Labrador_retriever',
#  'miniature_poodle',
#  'seat_belt',
#  'Italian_greyhound',
#  'snail',
#  'English_setter',
#  'miniature_schnauzer',
#  'Maltese_dog',
#  'Airedale',
# ...

# %%
image_predictions[image_predictions.jpg_url.duplicated()]
# Out:
#                 tweet_id                                            jpg_url  \
# 1297  752309394570878976  https://pbs.twimg.com/ext_tw_video_thumb/67535...
# 1315  754874841593970688    https://pbs.twimg.com/media/CWza7kpWcAAdYLc.jpg
# 1333  757729163776290825    https://pbs.twimg.com/media/CWyD2HGUYAQ1Xa7.jpg
# 1345  759159934323924993    https://pbs.twimg.com/media/CU1zsMSUAAAS0qW.jpg
# 1349  759566828574212096    https://pbs.twimg.com/media/CkNjahBXAAQ2kWo.jpg
# ...                  ...                                                ...
# 1903  851953902622658560    https://pbs.twimg.com/media/C4KHj-nWQAA3poV.jpg
# 1944  861769973181624320    https://pbs.twimg.com/media/CzG425nWgAAnP7P.jpg
# 1992  873697596434513921    https://pbs.twimg.com/media/DA7iHL5U0AA1OQo.jpg
# 2041  885311592912609280    https://pbs.twimg.com/media/C4bTH6nWMAAX_bJ.jpg
# 2055  888202515573088257    https://pbs.twimg.com/media/DFDw2tyUQAAAFke.jpg
#
# ...

# %%
image_predictions[image_predictions['p1_conf']==1]
# Out:
#                tweet_id                                          jpg_url  \
# 106  667866724293877760  https://pbs.twimg.com/media/CUS9PlUWwAANeAD.jpg
#
#      img_num             p1  p1_conf  p1_dog          p2       p2_conf  \
# 106        1  jigsaw_puzzle      1.0   False  prayer_rug  1.011300e-08
#
#      p2_dog       p3       p3_conf  p3_dog
# 106   False  doormat  1.740170e-10   False

# %% [markdown]
# ### Quality issues
# jpg_url column has duplicated values
#
# tweet_id is object

# %% [markdown]
# ## Assessment of add_data

# %%
list(add_data)
# Out:
# ['created_at',
#  'id',
#  'full_text',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'retweet_count',
#  'favorite_count',
#  'favorited',
#  'retweeted',
#  'lang']

# %%
add_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2333 entries, 0 to 2332
# Data columns (total 10 columns):
# created_at               2333 non-null object
# id                       2333 non-null int64
# full_text                2333 non-null object
# in_reply_to_status_id    77 non-null float64
# in_reply_to_user_id      77 non-null float64
# retweet_count            2333 non-null int64
# favorite_count           2333 non-null int64
# favorited                2333 non-null bool
# retweeted                2333 non-null bool
# lang                     2333 non-null object
# dtypes: bool(2), float64(2), int64(3), object(3)
# memory usage: 150.5+ KB

# %%
add_data.favorited.value_counts()
# Out:
# False    2333
# Name: favorited, dtype: int64

# %%
add_data.sample(15)
# Out:
#                           created_at                  id  \
# 439   Mon Jan 09 04:04:51 +0000 2017  818307523543449600
# 1141  Sat Apr 23 00:41:42 +0000 2016  723673163800948736
# 2182  Mon Nov 23 03:33:22 +0000 2015  668633411083464705
# 2033  Mon Nov 30 15:59:17 +0000 2015  671357843010908160
# 1801  Mon Dec 14 20:17:59 +0000 2015  676496375194980353
# 674   Sat Oct 15 02:04:45 +0000 2016  787111942498508800
# 2242  Fri Nov 20 02:47:56 +0000 2015  667534815156183040
# 748   Sun Sep 18 22:54:18 +0000 2016  777641927919427584
# 1803  Mon Dec 14 16:34:00 +0000 2015  676440007570247681
# 732   Thu Sep 22 20:33:42 +0000 2016  779056095788752897
# 176   Mon Apr 24 15:13:52 +0000 2017  856526610513747968
# 1623  Mon Jan 04 03:18:23 +0000 2016  683849932751646720
# 1399  Fri Feb 12 17:22:12 +0000 2016  698195409219559425
# 818   Sun Aug 21 02:47:37 +0000 2016  767191397493538821
# 878   Fri Jul 29 00:57:05 +0000 2016  758828659922702336
#
# ...

# %% [markdown]
# ### Quality issues
# not proper format for created_at
# created_at is datetime
# id is object
# full_text is string
#
# missing information for :in_reply_to_status_id, in_reply_to_user_id
#
# ## tidyness issues
# full_text column should contain only the tweet_text

# %% [markdown]
# # Assessment resume
#
# ## twiter_archive_enhance
# ### Quality issues
# - Missing information for : in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls.
# - erroneous data types for: tweet_id is an object not integer timestamp is datetime not object
# - not proper format for timestamp
#
# ### Tidyness issues
# - text column should be split into followers and tweet_text we have four columns for dog stage, we do need just one column
#
# ## image_predictions
# ### Quality issues
# - jpg_url column has duplicated values
# - tweet_id is object
#
# ## add_data
# ### Quality issues
# not proper format for created_at created_at is datetime id is object full_text is string
# missing information for :in_reply_to_status_id, in_reply_to_user_id
#
# ### tidyness issues
# full_text column should contain only the tweet_text

# %% [markdown]
# # Chapter 3: Cleaning process
# ## the cleaning process will be done on a copy of each table

# %% [markdown]
# ## issues to be cleaned by table
#
# ### twiter_archive_enhance, define
# for the missing information:, expanded_urls.
# Define : drop the following columns since we can't retrieve their values :
# - in_reply_to_status_id,
# - in_reply_to_user_id,
# - retweeted_status_id,
# - retweeted_status_user_id,
# - retweeted_status_timestamp
#
# Define:
# - retrieve the missing values for expanded_urls from predictive_image through jpg_url
#
# erroneous data types for:
# - convert tweet_id from integer to object
# - convert timestamp from object to datetime in a proper format
#
# Not proper format for timestamp, remove the last 5 characters +0000
#
# ### tidyness
# - split text column into two columns followers and tweet_text, and drop text column
# - create one column dog_stage from the four columns for dog stage
# - expanded_urls should be on predictive-image

# %%
# let's make a copy of twiter_archive_enhance
twiter_cleaned=twiter_archive_enhance.copy()

# %%
list(twiter_cleaned)
# Out:
# ['tweet_id',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'timestamp',
#  'source',
#  'text',
#  'retweeted_status_id',
#  'retweeted_status_user_id',
#  'retweeted_status_timestamp',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo']

# %%
# let's drop the following columns : in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id,retweeted_status_timestamp
twiter_cleaned=twiter_cleaned.drop(['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp'], axis=1)

# %%
list(twiter_cleaned)
# Out:
# ['tweet_id',
#  'timestamp',
#  'source',
#  'text',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo']

# %%
twiter_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2356 non-null int64
# timestamp             2356 non-null object
# source                2356 non-null object
# text                  2356 non-null object
# expanded_urls         2297 non-null object
# rating_numerator      2356 non-null int64
# rating_denominator    2356 non-null int64
# name                  2356 non-null object
# doggo                 2356 non-null object
# floofer               2356 non-null object
# pupper                2356 non-null object
# puppo                 2356 non-null object
# dtypes: int64(3), object(9)
# memory usage: 221.0+ KB

# %%
# let's retrieve the missing values for expanded_urls from predictive_image through jpg_url
# to retrieve, we gonna first create an expanded_urls missing record 
twiter_cleaned[twiter_cleaned['expanded_urls'].isnull()]
# Out:
#                 tweet_id                  timestamp  \
# 30    886267009285017600  2017-07-15 16:51:35 +0000
# 55    881633300179243008  2017-07-02 21:58:53 +0000
# 64    879674319642796034  2017-06-27 12:14:36 +0000
# 113   870726314365509632  2017-06-02 19:38:25 +0000
# 148   863427515083354112  2017-05-13 16:15:35 +0000
# 179   857214891891077121  2017-04-26 12:48:51 +0000
# 185   856330835276025856  2017-04-24 02:15:55 +0000
# 186   856288084350160898  2017-04-23 23:26:03 +0000
# 188   855862651834028034  2017-04-22 19:15:32 +0000
# 189   855860136149123072  2017-04-22 19:05:32 +0000
# 218   850333567704068097  2017-04-07 13:04:55 +0000
# 228   848213670039564288  2017-04-01 16:41:12 +0000
# 234   847617282490613760  2017-03-31 01:11:22 +0000
# 274   840698636975636481  2017-03-11 22:59:09 +0000
# 290   838150277551247360  2017-03-04 22:12:52 +0000
# 291   838085839343206401  2017-03-04 17:56:49 +0000
# 313   835246439529840640  2017-02-24 21:54:03 +0000
# ...

# %%
# let's convert tweet_id from integer to object
twiter_cleaned.tweet_id=twiter_cleaned.tweet_id.astype('object')

# %%
twiter_cleaned.timestamp=twiter_cleaned.timestamp.str[:-5]

# %%
twiter_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2356 non-null object
# timestamp             2356 non-null object
# source                2356 non-null object
# text                  2356 non-null object
# expanded_urls         2297 non-null object
# rating_numerator      2356 non-null int64
# rating_denominator    2356 non-null int64
# name                  2356 non-null object
# doggo                 2356 non-null object
# floofer               2356 non-null object
# pupper                2356 non-null object
# puppo                 2356 non-null object
# dtypes: int64(2), object(10)
# memory usage: 221.0+ KB

# %%
twiter_cleaned.sample(20)
# Out:
#                 tweet_id        timestamp  \
# 1601  686003207160610816  2016-01-10 01:5
# 1974  673148804208660480  2015-12-05 14:3
# 1618  684969860808454144  2016-01-07 05:2
# 1900  674664755118911488  2015-12-09 18:5
# 2256  667766675769573376  2015-11-20 18:0
# 522   809808892968534016  2016-12-16 17:1
# 833   768554158521745409  2016-08-24 21:0
# 1995  672594978741354496  2015-12-04 01:5
# 620   796125600683540480  2016-11-08 23:0
# 1946  673705679337693185  2015-12-07 03:2
# 645   793165685325201412  2016-10-31 19:0
# 906   758041019896193024  2016-07-26 20:4
# 921   756288534030475264  2016-07-22 00:4
# 504   813051746834595840  2016-12-25 16:0
# 1323  706265994973601792  2016-03-05 23:5
# 1475  693642232151285760  2016-01-31 03:4
# 358   830097400375152640  2017-02-10 16:5
# 2021  672082170312290304  2015-12-02 15:5
# 91    874434818259525634  2017-06-13 01:1
# 1330  705786532653883392  2016-03-04 16:0
#
#                                                  source  \
# ...

# %%
import datetime
#let's create a format for datetime called my_datetime
#time_format='%Y-%m-%d %H:%M'
twiter_cleaned.timestamp=pd.to_datetime(twiter_cleaned.timestamp)

# %%
twiter_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2356 non-null object
# timestamp             2356 non-null datetime64[ns]
# source                2356 non-null object
# text                  2356 non-null object
# expanded_urls         2297 non-null object
# rating_numerator      2356 non-null int64
# rating_denominator    2356 non-null int64
# name                  2356 non-null object
# doggo                 2356 non-null object
# floofer               2356 non-null object
# pupper                2356 non-null object
# puppo                 2356 non-null object
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 221.0+ KB

# %%
# convert name from object to string
twiter_cleaned.name=twiter_cleaned.name.astype('str')

# %%
twiter_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2356 non-null object
# timestamp             2356 non-null datetime64[ns]
# source                2356 non-null object
# text                  2356 non-null object
# expanded_urls         2297 non-null object
# rating_numerator      2356 non-null int64
# rating_denominator    2356 non-null int64
# name                  2356 non-null object
# doggo                 2356 non-null object
# floofer               2356 non-null object
# pupper                2356 non-null object
# puppo                 2356 non-null object
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 221.0+ KB

# %% [markdown]
# ### tidyness
# - create one column dog_stage from the four columns for dog stage

# %%
twiter_cleaned=pd.melt(twiter_cleaned, id_vars=['tweet_id','timestamp','source','text','expanded_urls','rating_numerator','rating_denominator','name'],var_name='dog_stage',value_name='stage')

# %%
twiter_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9424 entries, 0 to 9423
# Data columns (total 10 columns):
# tweet_id              9424 non-null object
# timestamp             9424 non-null datetime64[ns]
# source                9424 non-null object
# text                  9424 non-null object
# expanded_urls         9188 non-null object
# rating_numerator      9424 non-null int64
# rating_denominator    9424 non-null int64
# name                  9424 non-null object
# dog_stage             9424 non-null object
# stage                 9424 non-null object
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 736.4+ KB

# %%
twiter_cleaned.head()
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:02:00
# 1  892177421306343426 2017-08-01 00:01:00
# 2  891815181378084864 2017-07-31 00:01:00
# 3  891689557279858688 2017-07-30 15:05:00
# 4  891327558926688256 2017-07-29 16:00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %% [markdown]
# ## Cleaning, image_predictions
# tweet_id is object

# %%
list(image_predictions)
# Out:
# ['tweet_id',
#  'jpg_url',
#  'img_num',
#  'p1',
#  'p1_conf',
#  'p1_dog',
#  'p2',
#  'p2_conf',
#  'p2_dog',
#  'p3',
#  'p3_conf',
#  'p3_dog']

# %%
image_predictions_clean=image_predictions.copy()

# %%
# let's convert tweet_id to object
image_predictions_clean.tweet_id=image_predictions_clean.tweet_id.astype('object')

# %%
image_predictions_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null object
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %%
image_predictions_clean.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 1247  747600769478692864  https://pbs.twimg.com/media/CmAC7ehXEAAqSuW.jpg
# 1753  824663926340194305  https://pbs.twimg.com/media/C3HLd0HXUAAUI2b.jpg
# 425   674075285688614912  https://pbs.twimg.com/media/CVrL5YBWoAA_uPD.jpg
# 397   673662677122719744  https://pbs.twimg.com/media/CVlUfBbUwAQyfcD.jpg
# 1845  838921590096166913  https://pbs.twimg.com/media/C6Ryuf7UoAAFX4a.jpg
#
#       img_num                        p1   p1_conf  p1_dog                  p2  \
# 1247        1  Chesapeake_Bay_retriever  0.804363    True          Weimaraner
# 1753        1            English_setter  0.526488    True    golden_retriever
# 425         1                  Airedale  0.305392    True  Kerry_blue_terrier
# 397         1        Labrador_retriever  0.957670    True              beagle
# 1845        1            Border_terrier  0.664538    True   Brabancon_griffon
#
# ...

# %%
twiter_cleaned.sample(5)
# Out:
#                 tweet_id           timestamp  \
# 8222  725458796924002305 2016-04-27 22:57:10
# 2639  838952994649550848 2017-03-07 03:22:35
# 3325  750132105863102464 2016-07-05 01:00:05
# 9418  666050758794694657 2015-11-16 00:30:50
# 1384  700796979434098688 2016-02-19 21:39:54
#
#                                                  source  \
# 8222  <a href="http://twitter.com/download/iphone" r...
# 2639  <a href="http://twitter.com/download/iphone" r...
# 3325  <a href="http://twitter.com/download/iphone" r...
# 9418  <a href="http://twitter.com/download/iphone" r...
# 1384  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 8222  Pup had to be removed cuz it wouldn't have bee...
# 2639  SHE MISPLACED HER HOOMAN 13/10 MISTAKES HAPPEN...
# 3325  This is Stewie. He will roundhouse kick anyone...
# 9418  This is a truly beautiful English Wilson Staff...
# 1384  This is Daniel. He's a neat pup. Exotic af. Cu...
#
# ...

# %% [markdown]
# # Cleaning add_data
# ### Quality issues
# correct the format for created_at
# convert created_at to datetime
# convert id to object
# convert full_text to string
#
# for missing information related to :in_reply_to_status_id, in_reply_to_user_id, we will drop those columns
#
# ## tidyness issues
# full_text column should contain only the tweet_text

# %%
add_data_clean=add_data.copy()

# %%
list(add_data_clean)
# Out:
# ['created_at',
#  'id',
#  'full_text',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'retweet_count',
#  'favorite_count',
#  'favorited',
#  'retweeted',
#  'lang']

# %%
add_data_clean=add_data_clean.drop(['in_reply_to_status_id','in_reply_to_user_id'], axis=1)

# %%
list(add_data_clean)
# Out:
# ['created_at',
#  'id',
#  'full_text',
#  'retweet_count',
#  'favorite_count',
#  'favorited',
#  'retweeted',
#  'lang']

# %%
add_data_clean.sample(5)
# Out:
#                           created_at                  id  \
# 1651  Wed Dec 30 20:54:22 +0000 2015  682303737705140231
# 2244  Fri Nov 20 02:08:22 +0000 2015  667524857454854144
# 99    Thu Jun 08 01:06:27 +0000 2017  872620804844003328
# 68    Sun Jun 25 18:56:45 +0000 2017  879050749262655488
# 1757  Fri Dec 18 04:00:46 +0000 2015  677700003327029250
#
#                                               full_text  retweet_count  \
# 1651  This is Todo. He's screaming because he doesn'...            991
# 2244  Another topnotch dog. His name is Big Jumpy Ra...           1072
# 99    This is Monkey. She's supporting owners everyw...           3421
# 68    This is Steven. He has trouble relating to oth...           4335
# 1757  This is Ralph. He's an interpretive dancer. 10...           1443
#
#       favorite_count  favorited  retweeted lang
# 1651            3087      False      False   en
# 2244            1645      False      False   en
# ...

# %%
# let's correct the format of created_at and convert to datetime

import datetime
import pandas as pd

def reformat_date(date_series, old_format, new_format):
    return pd.to_datetime(date_series, format=old_format, errors='ignore').strftime(new_format)

date_series = pd.Series(add_data_clean.created_at)

old_format = '%a %b %d %H:%M:%S +%f0 %Y'
new_format = '%Y-%m-%d %H:%M:%S'

add_data_clean.created_at=date_series.apply(lambda x: reformat_date(x, old_format, new_format)).values

# %%
add_data_clean.created_at=pd.to_datetime(add_data_clean.created_at)

# %%
add_data_clean.sample(5)
# Out:
#               created_at                  id  \
# 780  2016-09-05 02:00:22  772615324260794368
# 205  2017-04-10 16:00:07  851464819735769094
# 2307 2015-11-16 21:10:36  666362758909284353
# 1076 2016-05-27 01:47:23  736010884653420544
# 305  2017-02-22 18:59:48  834477809192075265
#
#                                               full_text  retweet_count  \
# 780   RT @dog_rates: This is Gromit. He's pupset bec...           3484
# 205   This is Iggy. He was a rescue dog killed in th...           6995
# 2307  Unique dog here. Very small. Lives in containe...            531
# 1076  Right after you graduate vs when you remember ...           3023
# 305   RT @dog_rates: This is Leo. He was a skater pu...          10861
#
#       favorite_count  favorited  retweeted lang
# 780                0      False      False   en
# 205            24099      False      False   en
# 2307             734      False      False   en
# 1076            7968      False      False   en
# ...

# %%
add_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2333 entries, 0 to 2332
# Data columns (total 8 columns):
# created_at        2333 non-null datetime64[ns]
# id                2333 non-null int64
# full_text         2333 non-null object
# retweet_count     2333 non-null int64
# favorite_count    2333 non-null int64
# favorited         2333 non-null bool
# retweeted         2333 non-null bool
# lang              2333 non-null object
# dtypes: bool(2), datetime64[ns](1), int64(3), object(2)
# memory usage: 114.0+ KB

# %%
# let's convert id to object
add_data_clean.id=add_data_clean.id.astype('object')

# %%
list(twiter_cleaned)
# Out:
# ['tweet_id',
#  'timestamp',
#  'source',
#  'text',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'dog_stage',
#  'stage']

# %%
list(image_predictions_clean)
# Out:
# ['tweet_id',
#  'jpg_url',
#  'img_num',
#  'p1',
#  'p1_conf',
#  'p1_dog',
#  'p2',
#  'p2_conf',
#  'p2_dog',
#  'p3',
#  'p3_conf',
#  'p3_dog']

# %%
list(add_data_clean)
# Out:
# ['created_at',
#  'id',
#  'full_text',
#  'retweet_count',
#  'favorite_count',
#  'favorited',
#  'retweeted',
#  'lang']

# %%
# Let's rename the columns created_at and id from add_data_clean
add_data_clean = add_data_clean.rename(columns={'created_at': 'timestamp', 'id': 'tweet_id'})

# %%
add_data_clean.sample(2)
# Out:
#                timestamp            tweet_id  \
# 604  2016-11-08 20:00:55  796080075804475393
# 1470 2016-01-28 21:54:41  692828166163931137
#
#                                               full_text  retweet_count  \
# 604   This is Yogi. He's 98% floof. Snuggable af. 12...           2408
# 1470  This pupper just descended from heaven. 12/10 ...            891
#
#       favorite_count  favorited  retweeted lang
# 604             8770      False      False   en
# 1470            2901      False      False   en

# %% [markdown]
# # Analysis and visualization insight

# %% [markdown]
# ### image_predictions analysis
# We want to know for which breeds dogs the predictions work better

# %%
image_predictions_clean.p1.value_counts()
# Out:
# golden_retriever      150
# Labrador_retriever    100
# Pembroke               89
# Chihuahua              83
# pug                    57
#                      ...
# barbell                 1
# robin                   1
# damselfly               1
# tailed_frog             1
# studio_couch            1
# Name: p1, Length: 378, dtype: int64

# %% [markdown]
# We want to know how big is the gap between p1_conf, p2_conf and p3_conf. Actually, more the range is big, more accurate are the predictions

# %%
image_predictions.p1_conf.mean()
# Out:
# 0.5945482636144582

# %%
image_predictions.p2_conf.mean()
# Out:
# 0.13458860950039184

# %%
image_predictions.p3_conf.mean()
# Out:
# 0.06032416861810645

# %% [markdown]
# As we can see here the top 5 breeds dogs for which the predictions work well is : golden_retriever, labrador_retriever, Pembroke, Chihuahua and Pug
# As we noted, in 60% of the case the first image predicted can be the good dog choice.

# %% [markdown]
# ### twiter_cleaned analysis
# We want to know which stage is most popular

# %%
twiter_cleaned.stage.value_counts()
# Out:
# None       9030
# pupper      257
# doggo        97
# puppo        30
# floofer      10
# Name: stage, dtype: int64

# %% [markdown]
# ### add_data_clean analysis
#
# we are interested to see how retweet_count and favorite_count evolved during the period analyzed

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
add_data_clean.retweet_count.plot()

plt.show()

# %%
add_data_clean.favorite_count.plot()

plt.show()

# %%
twiter_cleaned.to_csv('twitter_archive_master.csv', index=False)

# %%
add_data_clean.to_csv('twitterapi.csv', index=False)

# %%
image_predictions_clean.to_csv('image.csv', index=False)
